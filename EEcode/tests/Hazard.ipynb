# %% [markdown]
# Author:
# Michael Evans,
# Senior Conservation Data Scientist,
# Center for Conservation Innovation,
# Defenders of Wildlife

# %%
# Initialize Google Earth Engine
import ee
ee.Authenticate()
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=6HsrvVvACJ-QLjUTHR_80Y48x0H7hXGvoOOZEyp9TNg&code_challenge_method=S256
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/xwGHZnWk-ah9jWgbT5xAZ_EFSS-Mj82HSVKr72nVBxqiZRNp2z6vWac
#
# Successfully saved authorization token.

# %%
# Mount Google Drive
from google.colab import drive
ROOT = '/content/drive'
drive.mount(ROOT)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from os.path import join

# %%
GIT_REPOSITORY = 'ACD_methods'
GIT_USERNAME = 'mjevans26'
GIT_TOKEN = "d9604f7bb70391909e16f6ea4fbd471553479c8e"
PROJECT_DIR = join(ROOT, 'My Drive/repos', GIT_REPOSITORY)
GITHUB_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print(GITHUB_PATH)
# Out:
# https://d9604f7bb70391909e16f6ea4fbd471553479c8e@github.com/mjevans26/ACD_methods.git

# %%
# Change the working directory to our git repo
# %cd {PROJECT_DIR}
# Out:
# /content/drive/My Drive/repos/ACD_methods

# %%
# Make sure we're working with the most up to date version of repo
# !git pull {GITHUB_PATH}
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 7 (delta 5), reused 7 (delta 5), pack-reused 0
# Unpacking objects: 100% (7/7), done.
# From https://github.com/mjevans26/ACD_methods
#  * branch            HEAD       -> FETCH_HEAD
# Updating 1abae06..d64a494
# Fast-forward
#  .spyproject/workspace.ini     | 2 +-
#  EEcode/Python/dictionaries.py | 8 ++++----
#  2 files changed, 5 insertions(+), 5 deletions(-)

# %%
# Add our repository modules to the path
import sys
sys.path.append(join(PROJECT_DIR, 'EEcode/Python'))
sys.path
# Out:
# ['/tensorflow-1.15.0/python3.6',
#  '',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/drive/My Drive/repos/ACD_methods/EEcode/Python']

# %%
import folium
import analyze
import dictionaries

# %% [markdown]
# ## Analysis

# %%
# Define our area of interest and date of change
aoi = ee.Geometry.Polygon(
        [[[-83.37017153264765, 37.48081395204879],
          [-83.37486536622822, 37.31933288374584],
          [-83.05319468739128, 37.30974497135589],
          [-83.05556035288436, 37.47934591201635]]])

doi = ee.Date('2018-08-01')

# %%
dictionary = dictionaries.forest
output = analyze.analyze_iw(aoi, doi, dictionary, 0)
# Out:
# Streaming output truncated to the last 5000 lines.
#                                                                                                                     "arguments": {
#                                                                                                                       "value": 1024
#                                                                                                                     },
#                                                                                                                     "functionName": "Image.constant"
#                                                                                                                   }
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.bitwiseAnd"
#                                                                                                               },
#                                                                                                               "image2": {
#                                                                                                                 "type": "Invocation",
#                                                                                                                 "arguments": {
#                                                                                                                   "value": 0
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.constant"
#                                                                                                               }
#                                                                                                             },
#                                                                                                             "functionName": "Image.eq"
#                                                                                                           },
#                                                                                                           "image2": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "image1": {
#                                                                                                                 "type": "Invocation",
#                                                                                                                 "arguments": {
#                                                                                                                   "image1": {
#                                                                                                                     "type": "Invocation",
#                                                                                                                     "arguments": {
#                                                                                                                       "value": {
#                                                                                                                         "type": "Invocation",
#                                                                                                                         "arguments": {
#                                                                                                                           "input": {
#                                                                                                                             "type": "ArgumentRef",
#                                                                                                                             "value": "_MAPPING_VAR_0_0"
#                                                                                                                           },
#                                                                                                                           "bandSelectors": [
#                                                                                                                             "QA60"
#                                                                                                                           ]
#                                                                                                                         },
#                                                                                                                         "functionName": "Image.select"
#                                                                                                                       }
#                                                                                                                     },
#                                                                                                                     "functionName": "Image.int16"
#                                                                                                                   },
#                                                                                                                   "image2": {
#                                                                                                                     "type": "Invocation",
#                                                                                                                     "arguments": {
#                                                                                                                       "value": 2048
#                                                                                                                     },
#                                                                                                                     "functionName": "Image.constant"
#                                                                                                                   }
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.bitwiseAnd"
#                                                                                                               },
#                                                                                                               "image2": {
#                                                                                                                 "type": "Invocation",
#                                                                                                                 "arguments": {
#                                                                                                                   "value": 0
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.constant"
#                                                                                                               }
#                                                                                                             },
#                                                                                                             "functionName": "Image.eq"
#                                                                                                           }
#                                                                                                         },
#                                                                                                         "functionName": "Image.and"
#                                                                                                       }
#                                                                                                     },
#                                                                                                     "functionName": "Image.updateMask"
#                                                                                                   },
#                                                                                                   "property": "MEAN_INCIDENCE_AZIMUTH_ANGLE_B8"
#                                                                                                 },
#                                                                                                 "functionName": "Element.get"
#                                                                                               }
#                                                                                             },
#                                                                                             "functionName": "Element.set"
#                                                                                           },
#                                                                                           "key": "viewing_zenith",
#                                                                                           "value": {
#                                                                                             "type": "Invocation",
#                                                                                             "arguments": {
#                                                                                               "object": {
#                                                                                                 "type": "Invocation",
#                                                                                                 "arguments": {
#                                                                                                   "image": {
#                                                                                                     "type": "ArgumentRef",
#                                                                                                     "value": "_MAPPING_VAR_0_0"
#                                                                                                   },
#                                                                                                   "mask": {
#                                                                                                     "type": "Invocation",
#                                                                                                     "arguments": {
#                                                                                                       "image1": {
#                                                                                                         "type": "Invocation",
#                                                                                                         "arguments": {
#                                                                                                           "image1": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "image1": {
#                                                                                                                 "type": "Invocation",
#                                                                                                                 "arguments": {
#                                                                                                                   "value": {
#                                                                                                                     "type": "Invocation",
#                                                                                                                     "arguments": {
#                                                                                                                       "input": {
#                                                                                                                         "type": "ArgumentRef",
#                                                                                                                         "value": "_MAPPING_VAR_0_0"
#                                                                                                                       },
#                                                                                                                       "bandSelectors": [
#                                                                                                                         "QA60"
#                                                                                                                       ]
#                                                                                                                     },
#                                                                                                                     "functionName": "Image.select"
#                                                                                                                   }
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.int16"
#                                                                                                               },
#                                                                                                               "image2": {
#                                                                                                                 "type": "Invocation",
#                                                                                                                 "arguments": {
#                                                                                                                   "value": 1024
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.constant"
#                                                                                                               }
#                                                                                                             },
#                                                                                                             "functionName": "Image.bitwiseAnd"
#                                                                                                           },
#                                                                                                           "image2": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "value": 0
#                                                                                                             },
#                                                                                                             "functionName": "Image.constant"
#                                                                                                           }
#                                                                                                         },
#                                                                                                         "functionName": "Image.eq"
#                                                                                                       },
#                                                                                                       "image2": {
#                                                                                                         "type": "Invocation",
#                                                                                                         "arguments": {
#                                                                                                           "image1": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "image1": {
#                                                                                                                 "type": "Invocation",
#                                                                                                                 "arguments": {
#                                                                                                                   "value": {
#                                                                                                                     "type": "Invocation",
#                                                                                                                     "arguments": {
#                                                                                                                       "input": {
#                                                                                                                         "type": "ArgumentRef",
#                                                                                                                         "value": "_MAPPING_VAR_0_0"
#                                                                                                                       },
#                                                                                                                       "bandSelectors": [
#                                                                                                                         "QA60"
#                                                                                                                       ]
#                                                                                                                     },
#                                                                                                                     "functionName": "Image.select"
#                                                                                                                   }
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.int16"
#                                                                                                               },
#                                                                                                               "image2": {
#                                                                                                                 "type": "Invocation",
#                                                                                                                 "arguments": {
#                                                                                                                   "value": 2048
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.constant"
#                                                                                                               }
#                                                                                                             },
#                                                                                                             "functionName": "Image.bitwiseAnd"
#                                                                                                           },
#                                                                                                           "image2": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "value": 0
#                                                                                                             },
#                                                                                                             "functionName": "Image.constant"
#                                                                                                           }
#                                                                                                         },
#                                                                                                         "functionName": "Image.eq"
#                                                                                                       }
#                                                                                                     },
#                                                                                                     "functionName": "Image.and"
#                                                                                                   }
#                                                                                                 },
#                                                                                                 "functionName": "Image.updateMask"
#                                                                                               },
#                                                                                               "property": "MEAN_INCIDENCE_ZENITH_ANGLE_B8"
#                                                                                             },
#                                                                                             "functionName": "Element.get"
#                                                                                           }
#                                                                                         },
#                                                                                         "functionName": "Element.set"
#                                                                                       },
#                                                                                       "key": "CLOUDY_PIXEL_PERCENTAGE",
#                                                                                       "value": {
#                                                                                         "type": "Invocation",
#                                                                                         "arguments": {
#                                                                                           "object": {
#                                                                                             "type": "Invocation",
#                                                                                             "arguments": {
#                                                                                               "image": {
#                                                                                                 "type": "ArgumentRef",
#                                                                                                 "value": "_MAPPING_VAR_0_0"
#                                                                                               },
#                                                                                               "mask": {
#                                                                                                 "type": "Invocation",
#                                                                                                 "arguments": {
#                                                                                                   "image1": {
#                                                                                                     "type": "Invocation",
#                                                                                                     "arguments": {
#                                                                                                       "image1": {
#                                                                                                         "type": "Invocation",
#                                                                                                         "arguments": {
#                                                                                                           "image1": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "value": {
#                                                                                                                 "type": "Invocation",
#                                                                                                                 "arguments": {
#                                                                                                                   "input": {
#                                                                                                                     "type": "ArgumentRef",
#                                                                                                                     "value": "_MAPPING_VAR_0_0"
#                                                                                                                   },
#                                                                                                                   "bandSelectors": [
#                                                                                                                     "QA60"
#                                                                                                                   ]
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.select"
#                                                                                                               }
#                                                                                                             },
#                                                                                                             "functionName": "Image.int16"
#                                                                                                           },
#                                                                                                           "image2": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "value": 1024
#                                                                                                             },
#                                                                                                             "functionName": "Image.constant"
#                                                                                                           }
#                                                                                                         },
#                                                                                                         "functionName": "Image.bitwiseAnd"
#                                                                                                       },
#                                                                                                       "image2": {
#                                                                                                         "type": "Invocation",
#                                                                                                         "arguments": {
#                                                                                                           "value": 0
#                                                                                                         },
#                                                                                                         "functionName": "Image.constant"
#                                                                                                       }
#                                                                                                     },
#                                                                                                     "functionName": "Image.eq"
#                                                                                                   },
#                                                                                                   "image2": {
#                                                                                                     "type": "Invocation",
#                                                                                                     "arguments": {
#                                                                                                       "image1": {
#                                                                                                         "type": "Invocation",
#                                                                                                         "arguments": {
#                                                                                                           "image1": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "value": {
#                                                                                                                 "type": "Invocation",
#                                                                                                                 "arguments": {
#                                                                                                                   "input": {
#                                                                                                                     "type": "ArgumentRef",
#                                                                                                                     "value": "_MAPPING_VAR_0_0"
#                                                                                                                   },
#                                                                                                                   "bandSelectors": [
#                                                                                                                     "QA60"
#                                                                                                                   ]
#                                                                                                                 },
#                                                                                                                 "functionName": "Image.select"
#                                                                                                               }
#                                                                                                             },
#                                                                                                             "functionName": "Image.int16"
#                                                                                                           },
#                                                                                                           "image2": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "value": 2048
#                                                                                                             },
#                                                                                                             "functionName": "Image.constant"
#                                                                                                           }
#                                                                                                         },
#                                                                                                         "functionName": "Image.bitwiseAnd"
#                                                                                                       },
#                                                                                                       "image2": {
#                                                                                                         "type": "Invocation",
#                                                                                                         "arguments": {
#                                                                                                           "value": 0
#                                                                                                         },
#                                                                                                         "functionName": "Image.constant"
#                                                                                                       }
#                                                                                                     },
#                                                                                                     "functionName": "Image.eq"
#                                                                                                   }
#                                                                                                 },
#                                                                                                 "functionName": "Image.and"
#                                                                                               }
#                                                                                             },
#                                                                                             "functionName": "Image.updateMask"
#                                                                                           },
#                                                                                           "property": "CLOUDY_PIXEL_PERCENTAGE"
#                                                                                         },
#                                                                                         "functionName": "Element.get"
#                                                                                       }
#                                                                                     },
#                                                                                     "functionName": "Element.set"
#                                                                                   }
#                                                                                 },
#                                                                                 "functionName": "Image.addBands"
#                                                                               },
#                                                                               "bandNames": [
#                                                                                 "B8",
#                                                                                 "B11"
#                                                                               ]
#                                                                             },
#                                                                             "functionName": "Image.normalizedDifference"
#                                                                           },
#                                                                           "img": {
#                                                                             "type": "Invocation",
#                                                                             "arguments": {
#                                                                               "input": {
#                                                                                 "type": "Invocation",
#                                                                                 "arguments": {
#                                                                                   "dstImg": {
#                                                                                     "type": "Invocation",
#                                                                                     "arguments": {
#                                                                                       "input": {
#                                                                                         "type": "Invocation",
#                                                                                         "arguments": {
#                                                                                           "image": {
#                                                                                             "type": "ArgumentRef",
#                                                                                             "value": "_MAPPING_VAR_0_0"
#                                                                                           },
#                                                                                           "mask": {
#                                                                                             "type": "Invocation",
#                                                                                             "arguments": {
#                                                                                               "image1": {
#                                                                                                 "type": "Invocation",
#                                                                                                 "arguments": {
#                                                                                                   "image1": {
#                                                                                                     "type": "Invocation",
#                                                                                                     "arguments": {
#                                                                                                       "image1": {
#                                                                                                         "type": "Invocation",
#                                                                                                         "arguments": {
#                                                                                                           "value": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "input": {
#                                                                                                                 "type": "ArgumentRef",
#                                                                                                                 "value": "_MAPPING_VAR_0_0"
#                                                                                                               },
#                                                                                                               "bandSelectors": [
#                                                                                                                 "QA60"
#                                                                                                               ]
#                                                                                                             },
#                                                                                                             "functionName": "Image.select"
#                                                                                                           }
#                                                                                                         },
#                                                                                                         "functionName": "Image.int16"
#                                                                                                       },
#                                                                                                       "image2": {
#                                                                                                         "type": "Invocation",
#                                                                                                         "arguments": {
#                                                                                                           "value": 1024
#                                                                                                         },
#                                                                                                         "functionName": "Image.constant"
#                                                                                                       }
#                                                                                                     },
#                                                                                                     "functionName": "Image.bitwiseAnd"
#                                                                                                   },
#                                                                                                   "image2": {
#                                                                                                     "type": "Invocation",
#                                                                                                     "arguments": {
#                                                                                                       "value": 0
#                                                                                                     },
#                                                                                                     "functionName": "Image.constant"
#                                                                                                   }
#                                                                                                 },
#                                                                                                 "functionName": "Image.eq"
#                                                                                               },
#                                                                                               "image2": {
#                                                                                                 "type": "Invocation",
#                                                                                                 "arguments": {
#                                                                                                   "image1": {
#                                                                                                     "type": "Invocation",
#                                                                                                     "arguments": {
#                                                                                                       "image1": {
#                                                                                                         "type": "Invocation",
#                                                                                                         "arguments": {
#                                                                                                           "value": {
#                                                                                                             "type": "Invocation",
#                                                                                                             "arguments": {
#                                                                                                               "input": {
#                                                                                                                 "type": "ArgumentRef",
#                                                                                                                 "value": "_MAPPING_VAR_0_0"
#                                                                                                               },
#                                                                                                               "bandSelectors": [
#                                                                                                                 "QA60"
#                                                                                                               ]
# ...
#                                                                                             "arguments": {
#                                                                                               "input": {
#                                                                                                 "type": "ArgumentRef",
#                                                                                                 "value": "_MAPPING_VAR_0_0"
#                                                                                               },
#                                                                                               "bandSelectors": [
#                                                                                                 "B1",
#                                                                                                 "B2",
#                                                                                                 "B3",
#                                                                                                 "B4",
#                                                                                                 "B5",
#                                                                                                 "B6",
#                                                                                                 "B7",
#                                                                                                 "B8",
#                                                                                                 "B8A",
#                                                                                                 "B9",
#                                                                                                 "B10",
#                                                                                                 "B11",
#                                                                                                 "B12"
#                                                                                               ]
#                                                                                             },
#                                                                                             "functionName": "Image.select"
#                                                                                           },
#                                                                                           "image2": {
#                                                                                             "type": "Invocation",
#                                                                                             "arguments": {
#                                                                                               "value": 10000
#                                                                                             },
#                                                                                             "functionName": "Image.constant"
#                                                                                           }
#                                                                                         },
#                                                                                         "functionName": "Image.divide"
#                                                                                       },
#                                                                                       "key": "solar_azimuth",
#                                                                                       "value": {
#                                                                                         "type": "Invocation",
#                                                                                         "arguments": {
#                                                                                           "object": {
#                                                                                             "type": "ArgumentRef",
#                                                                                             "value": "_MAPPING_VAR_0_0"
#                                                                                           },
#                                                                                           "property": "MEAN_SOLAR_AZIMUTH_ANGLE"
#                                                                                         },
#                                                                                         "functionName": "Element.get"
#                                                                                       }
#                                                                                     },
#                                                                                     "functionName": "Element.set"
#                                                                                   },
#                                                                                   "key": "solar_zenith",
#                                                                                   "value": {
#                                                                                     "type": "Invocation",
#                                                                                     "arguments": {
#                                                                                       "object": {
#                                                                                         "type": "ArgumentRef",
#                                                                                         "value": "_MAPPING_VAR_0_0"
#                                                                                       },
#                                                                                       "property": "MEAN_SOLAR_ZENITH_ANGLE"
#                                                                                     },
#                                                                                     "functionName": "Element.get"
#                                                                                   }
#                                                                                 },
#                                                                                 "functionName": "Element.set"
#                                                                               },
#                                                                               "key": "viewing_azimuth",
#                                                                               "value": {
#                                                                                 "type": "Invocation",
#                                                                                 "arguments": {
#                                                                                   "object": {
#                                                                                     "type": "ArgumentRef",
#                                                                                     "value": "_MAPPING_VAR_0_0"
#                                                                                   },
#                                                                                   "property": "MEAN_INCIDENCE_AZIMUTH_ANGLE_B8"
#                                                                                 },
#                                                                                 "functionName": "Element.get"
#                                                                               }
#                                                                             },
#                                                                             "functionName": "Element.set"
#                                                                           },
#                                                                           "key": "viewing_zenith",
#                                                                           "value": {
#                                                                             "type": "Invocation",
#                                                                             "arguments": {
#                                                                               "object": {
#                                                                                 "type": "ArgumentRef",
#                                                                                 "value": "_MAPPING_VAR_0_0"
#                                                                               },
#                                                                               "property": "MEAN_INCIDENCE_ZENITH_ANGLE_B8"
#                                                                             },
#                                                                             "functionName": "Element.get"
#                                                                           }
#                                                                         },
#                                                                         "functionName": "Element.set"
#                                                                       },
#                                                                       "key": "CLOUDY_PIXEL_PERCENTAGE",
#                                                                       "value": {
#                                                                         "type": "Invocation",
#                                                                         "arguments": {
#                                                                           "object": {
#                                                                             "type": "ArgumentRef",
#                                                                             "value": "_MAPPING_VAR_0_0"
#                                                                           },
#                                                                           "property": "CLOUDY_PIXEL_PERCENTAGE"
#                                                                         },
#                                                                         "functionName": "Element.get"
#                                                                       }
#                                                                     },
#                                                                     "functionName": "Element.set"
#                                                                   }
#                                                                 },
#                                                                 "functionName": "Image.addBands"
#                                                               },
#                                                               "bandNames": [
#                                                                 "B3",
#                                                                 "B11"
#                                                               ]
#                                                             },
#                                                             "functionName": "Image.normalizedDifference"
#                                                           }
#                                                         },
#                                                         "function": {
#                                                           "type": "Invocation",
#                                                           "arguments": {
#                                                             "expression": "img",
#                                                             "argName": "DEFAULT_EXPRESSION_IMAGE",
#                                                             "vars": [
#                                                               "DEFAULT_EXPRESSION_IMAGE",
#                                                               "img"
#                                                             ]
#                                                           },
#                                                           "functionName": "Image.parseExpression"
#                                                         }
#                                                       },
#                                                       "image2": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "value": 0.3
#                                                         },
#                                                         "functionName": "Image.constant"
#                                                       }
#                                                     },
#                                                     "functionName": "Image.subtract"
#                                                   },
#                                                   "image2": {
#                                                     "type": "Invocation",
#                                                     "arguments": {
#                                                       "value": 0.5
#                                                     },
#                                                     "functionName": "Image.constant"
#                                                   }
#                                                 },
#                                                 "functionName": "Image.divide"
#                                               }
#                                             },
#                                             "functionName": "Image.min"
#                                           },
#                                           "low": 0,
#                                           "high": 1
#                                         },
#                                         "functionName": "Image.clamp"
#                                       },
#                                       "names": [
#                                         "waterScore"
#                                       ]
#                                     },
#                                     "functionName": "Image.rename"
#                                   },
#                                   "bandSelectors": [
#                                     "waterScore"
#                                   ]
#                                 },
#                                 "functionName": "Image.select"
#                               },
#                               "image2": {
#                                 "type": "Invocation",
#                                 "arguments": {
#                                   "value": 0.5
#                                 },
#                                 "functionName": "Image.constant"
#                               }
#                             },
#                             "functionName": "Image.lte"
#                           }
#                         },
#                         "functionName": "Image.and"
#                       }
#                     },
#                     "functionName": "Image.updateMask"
#                   }
#                 }
#               },
#               "functionName": "Collection.map"
#             }
#           },
#           "functionName": "Collection.first"
#         }
#       },
#       "functionName": "Image.bandNames"
#     },
#     "other": [
#       "B2",
#       "B3",
#       "B4",
#       "B8",
#       "B11",
#       "B12"
#     ]
#   },
#   "functionName": "List.removeAll"
# })
# before size: 232
#
# *******************************
# Unexpected error in analyze.py
# <class 'ee.ee_exception.EEException'> analyze.py 125
# Error: Dictionary.toImage: Dictionary does not contain key: 'rcvmax_z'.
# *******************************

# %%
# View the outputs using Leaflet
vis_params = {
        'palette': ['ffffff', 'd63000'],
        'min': 80,
        'max': 200}
        
my_map = folium.Map(location=[37.4, -83.15], zoom_start=12)

# Add the elevation model to the map object.
my_map.add_ee_layer(output.get('chi2'), vis_params, 'chi2')

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())
